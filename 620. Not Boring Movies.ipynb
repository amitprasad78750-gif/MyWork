# %% [markdown]
# Write a solution to report the movies with an odd-numbered ID and a description that is not "boring".
#
# Return the result table ordered by rating in descending order.
#
# The result format is in the following example.
#
#
#
# Example 1:
#
# Input:
# Cinema table:
# +----+------------+-------------+--------+
# | id | movie      | description | rating |
# +----+------------+-------------+--------+
# | 1  | War        | great 3D    | 8.9    |
# | 2  | Science    | fiction     | 8.5    |
# | 3  | irish      | boring      | 6.2    |
# | 4  | Ice song   | Fantacy     | 8.6    |
# | 5  | House card | Interesting | 9.1    |
# +----+------------+-------------+--------+
# Output:
# +----+------------+-------------+--------+
# | id | movie      | description | rating |
# +----+------------+-------------+--------+
# | 5  | House card | Interesting | 9.1    |
# | 1  | War        | great 3D    | 8.9    |
# +----+------------+-------------+--------+

# %% [markdown]
# ## Taking Pandas Data Frame from leetcode and converting this into Spark Data Frame

# %%
import pandas as pd
data = [[1, 'War', 'great 3D', 8.9], [2, 'Science', 'fiction', 8.5], [3, 'irish', 'boring', 6.2], [4, 'Ice song', 'Fantacy', 8.6], [5, 'House card', 'Interesting', 9.1]]
cinema = pd.DataFrame(data, columns=['id', 'movie', 'description', 'rating']).astype({'id':'Int64', 'movie':'object', 'description':'object', 'rating':'Float64'})

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Boring Movies").getOrCreate()
cinema_df=spark.createDataFrame(cinema)
cinema_df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/18 14:00:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +---+----------+-----------+------+
# | id|     movie|description|rating|
# +---+----------+-----------+------+
# |  1|       War|   great 3D|   8.9|
# |  2|   Science|    fiction|   8.5|
# |  3|     irish|     boring|   6.2|
# |  4|  Ice song|    Fantacy|   8.6|
# |  5|House card|Interesting|   9.1|
# +---+----------+-----------+------+
# 26/07/18 14:00:28 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
from pyspark.sql.functions import col
df=cinema_df.filter((col("description")!='boring') & (col("id") %2 !=0))
df.show()
# Out:
# +---+----------+-----------+------+
# | id|     movie|description|rating|
# +---+----------+-----------+------+
# |  1|       War|   great 3D|   8.9|
# |  5|House card|Interesting|   9.1|
# +---+----------+-----------+------+
