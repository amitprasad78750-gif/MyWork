# %% [markdown]
# Table: World
#
# +-------------+---------+
# | Column Name | Type    |
# +-------------+---------+
# | name        | varchar |
# | continent   | varchar |
# | area        | int     |
# | population  | int     |
# | gdp         | bigint  |
# +-------------+---------+
# name is the primary key (column with unique values) for this table.
# Each row of this table gives information about the name of a country, the continent to which it belongs, its area, the population, and its GDP value.
#
#
# A country is big if:
#
# it has an area of at least three million (i.e., 3000000 km2), or
# it has a population of at least twenty-five million (i.e., 25000000).
# Write a solution to find the name, population, and area of the big countries.
#
# Return the result table in any order.
#
# The result format is in the following example.

# %% [markdown]
# ## import and ctreating spark Session

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("big country").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/26 04:37:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/05/26 04:37:33 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %% [markdown]
# ## leetcode data import below

# %%
import pandas as pd
data = [['Afghanistan', 'Asia', 652230, 25500100, 20343000000], ['Albania', 'Europe', 28748, 2831741, 12960000000], ['Algeria', 'Africa', 2381741, 37100000, 188681000000], ['Andorra', 'Europe', 468, 78115, 3712000000], ['Angola', 'Africa', 1246700, 20609294, 100990000000]]
world = pd.DataFrame(data, columns=['name', 'continent', 'area', 'population', 'gdp']).astype({'name':'object', 'continent':'object', 'area':'Int64', 'population':'Int64', 'gdp':'Int64'})

# %% [markdown]
# ## creating spark dataframe from pandas data from pands

# %%
df=spark.createDataFrame(world)
df.show()
# Out:
# +-----------+---------+-------+----------+------------+
# |       name|continent|   area|population|         gdp|
# +-----------+---------+-------+----------+------------+
# |Afghanistan|     Asia| 652230|  25500100| 20343000000|
# |    Albania|   Europe|  28748|   2831741| 12960000000|
# |    Algeria|   Africa|2381741|  37100000|188681000000|
# |    Andorra|   Europe|    468|     78115|  3712000000|
# |     Angola|   Africa|1246700|  20609294|100990000000|
# +-----------+---------+-------+----------+------------+

# %%
df1= df.select("name","population","area").filter("area>=3000000 or population >=25000000")
df1.show()
# Out:
# +-----------+----------+-------+
# |       name|population|   area|
# +-----------+----------+-------+
# |Afghanistan|  25500100| 652230|
# |    Algeria|  37100000|2381741|
# +-----------+----------+-------+

# %% [markdown]
# ## now creating temp View table

# %%
df1.createOrReplaceTempView("World")

# %% [markdown]
# ## writing spark SQl query to retrive result

# %%
df2=spark.sql("""
          select 
              name, 
              population, 
              area
          from World
          where area>=3000000 or population >=25000000    
""")
df2.show()
# Out:
# +-----------+----------+-------+
# |       name|population|   area|
# +-----------+----------+-------+
# |Afghanistan|  25500100| 652230|
# |    Algeria|  37100000|2381741|
# +-----------+----------+-------+
